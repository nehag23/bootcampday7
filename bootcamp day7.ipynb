# %%
import requests
import os
from datetime import datetime
import json

api_key='AIzaSyCmU2cmJn4f6x5xM13nzqfXPAP9UaCGlq4'
location=input("Enter the city name:")
Complete_api_link="http://api.openweathermap.org/data/2.5/weather?"+location+"+api_key"
api_link=requests.get(Complete_api_link)
api_data=api_link.json()

temp_city=((api_data['main']['temp'])-273.15)
weather_desc=api_data['weather'][0]['description']
hmdt=api_data['main']['humidity']
wind_spd=api_data['main']['speed']
date_time=datetime.now().strftime("%d %b %Y | %I:%M:%S %p")

print("Weather statistics - {} || {}".format(location.upper(),date_time))

print("temperature is : {:2f} deg C".format(temp_city))
print("Weather is:",weather_desc)
print("Humidity is:",hmdt,'%')
print("Wind speed is:",wind_spd,'kmph')
# Out:
# Enter the city name:mUMBAI
# Weather statistics - MUMBAI || 23 Jun 2021 | 02:54:21 PM
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-235fddf6001b> in <module>()
#      18 print("Weather statistics - {} || {}".format(location.upper(),date_time))
#      19
# ---> 20 print("temperature is : {:2f} deg C".format(temp_city))
#      21 print("Weather is:",weather_desc)
#      22 print("Humidity is:",hmdt,'%')
#
# NameError: name 'temp_city' is not defined
